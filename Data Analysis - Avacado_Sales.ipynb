# %% [markdown]
# # Part 1 Question 2: Analyze the avocado data

# %%
import pandas as pd

# %%
#1
data_url = 'datasets/avocado.csv'
df = pd.read_csv(data_url)

# %%
#2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.shape
# Out:
# (18249, 14)

# %%
#3
df.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %%
#4
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
#5
with pd.option_context(
    'display.max_rows', 10,
    'display.max_columns', 8,
):
    display(df)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume  ...  XLarge Bags  \
# 0               0  2015-12-27          1.33      64236.62  ...          0.0
# 1               1  2015-12-20          1.35      54876.98  ...          0.0
# 2               2  2015-12-13          0.93     118220.22  ...          0.0
# 3               3  2015-12-06          1.08      78992.15  ...          0.0
# 4               4  2015-11-29          1.28      51039.60  ...          0.0
# ...           ...         ...           ...           ...  ...          ...
# 18244           7  2018-02-04          1.63      17074.83  ...          0.0
# 18245           8  2018-01-28          1.71      13888.04  ...          0.0
# 18246           9  2018-01-21          1.87      13766.76  ...          0.0
# 18247          10  2018-01-14          1.93      16205.22  ...          0.0
# 18248          11  2018-01-07          1.62      17489.58  ...          0.0
#
#                type  year            region
# ...

# %%
#6
df[['Date', 'AveragePrice', 'Total Volume']].head()
# Out:
#          Date  AveragePrice  Total Volume
# 0  2015-12-27          1.33      64236.62
# 1  2015-12-20          1.35      54876.98
# 2  2015-12-13          0.93     118220.22
# 3  2015-12-06          1.08      78992.15
# 4  2015-11-29          1.28      51039.60

# %%
#7
df.AveragePrice
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
#8
df['EstimatedRevenue'] = df['AveragePrice'] * df['Total Volume']

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  EstimatedRevenue
# 0  2015  Albany        85434.7046
# ...

# %%
#9
priceByRegion = pd.DataFrame(df.groupby(['region', 'type'])['AveragePrice'].mean())

# %%
priceByRegion.reset_index(inplace=True)

# %%
priceByRegion.head()
# Out:
#                 region          type  AveragePrice
# 0               Albany  conventional      1.348757
# 1               Albany       organic      1.773314
# 2              Atlanta  conventional      1.068817
# 3              Atlanta       organic      1.607101
# 4  BaltimoreWashington  conventional      1.344201

# %%
#10
df.groupby('year')['Total Volume'].agg(['mean', 'median', 'std']).plot.bar()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# # Questions

# %% [markdown]
# 1. How many unique regions are there?

# %%
df['region'].nunique()
# Out:
# 54

# %% [markdown]
# 2. What is the average price for each type of avocado (organic and conventional)?s

# %%
df.groupby('type')['AveragePrice'].mean()
# Out:
# type
# conventional    1.158040
# organic         1.653999
# Name: AveragePrice, dtype: float64

# %% [markdown]
# 3. Which region has the lowest average price for organic avocados?

# %%
priceByRegion.query('type == "organic"').sort_values(by="AveragePrice").head(1)
# Out:
#      region     type  AveragePrice
# 37  Houston  organic      1.270769

# %% [markdown]
# 4. Have the Total Bags sold per year of each type of avocado become more or less consistent over time?

# %%
df.groupby(['year', 'type'])['Total Bags'].count().plot.barh()
# Out:
# <Axes: ylabel='year,type'>

# %% [markdown]
# - Total Bags sold per year for each type of avocado was consistent from 2015 to 2017. A sudden drop in the year 2018 in Total Bags sold indicates a plausible issue with the harvest.
